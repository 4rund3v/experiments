# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
expense_data = pd.read_excel("../expense_report.xlsx", sheet_name=None)

# %%
expense_data
# Out:
# {'Jan': Empty DataFrame
#  Columns: []
#  Index: [], 'Feb': Empty DataFrame
#  Columns: []
#  Index: [], 'March':      Txn Date Value Date                                        Description  \
#  0  2020-03-02 2020-03-02     BULK POSTING-     00000007080 210220 SANGAM...
#  1  2020-03-03 2020-03-03     by debit card-OTHPG 909630      ONE97 COMMU...
#  2  2020-03-03 2020-03-03     TO TRANSFER-UPI/DR/006308680849/PAVITHRA/SB...
#  3  2020-03-04 2020-03-04     DEBIT-ATMCard AMC  559601*7320 SILVER-GLOBAL--
#  4  2020-03-05 2020-03-05     BULK POSTING-     00000007080 290220 SREE B...
#  5  2020-03-09 2020-03-09  BY CLEARING / CHEQUE-CHB   BY CLEARING CHQ 243...
#  6  2020-03-12 2020-03-12     BY TRANSFER-INB Payment towards loan repaym...
#  7  2020-03-12 2020-03-12     TO TRANSFER-UPI/DR/007208486376/PAVITHRA/SB...
#  8  2020-03-14 2020-03-14     by debit card-OTHPG 763017      APPLE.COM/B...
#  9  2020-03-14 2020-03-14     TO TRANSFER-INB Payment towards loan repaym...
# ...

# %%
df = expense_data['March']
df.describe()
# Out:
# c:\users\arun\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#
# c:\users\arun\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#                    Txn Date           Value Date  \
# count                    21                   21
# unique                   14                   14
# top     2020-03-16 00:00:00  2020-03-16 00:00:00
# freq                      4                    4
# ...

# %%
df.plot(kind='bar', x='Debit', y='Balance', color='red')
plt.show() # not working
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\arun\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Debit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-9cbdeceeaca4> in <module>
# ...

# %%
df.columns
# Out:
# Index(['Txn Date', 'Value Date', 'Description', 'Ref No./Cheque No.',
#        '        Debit', 'Credit', 'Balance'],
#       dtype='object')

# %%
df.plot(kind="bar",
        x="Balance",
        y="Txn Date")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\arun\appdata\local\programs\python\python36\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# c:\users\arun\appdata\local\programs\python\python36\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     179         # the background is transparent
#     180         ticksLight = _is_light([label.get_color()
# --> 181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#     183                                 for label in axis.get_ticklabels()])
#
# ...

# %%
df.plot()
